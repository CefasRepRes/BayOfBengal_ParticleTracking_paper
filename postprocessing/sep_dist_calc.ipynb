# %%
import matplotlib.pyplot as plt
import numpy as np
import cartopy
import cartopy.crs as ccrs
import datetime
from netCDF4 import Dataset
import pandas as pd
import geopy.distance
import csv

# %%
drifter_data = '/gpfs/home/rpe16nbu/projects/ocpp_mo1/data/misc/drifter_6hour_undrogued_only.csv'

# %%
# Note that I have trimmed the data file to take out the header and column headings - the original file is in my OneDrive
cols = ["WMO", "time", "latitiude", "longitude"]
data_df = pd.read_csv(drifter_data, sep=",", skipinitialspace=True, header = 1, names=cols)

# %%
### CHANGE ###         
# Cop/ROMS, colour, wk
out_fname = '/gpfs/home/rpe16nbu/projects/ocpp_mo1/data/output/paper_data/validation/sep_dist_ROMS_green_wk43.csv'

# %%
### CHANGE ###
# lat_drifter = data_df.latitiude[data_df.WMO==4101590] # yellow
# lon_drifter = data_df.longitude[data_df.WMO==4101590]
# lat_drifter = data_df.latitiude[data_df.WMO==2301617] # red
# lon_drifter = data_df.longitude[data_df.WMO==2301617]
# lat_drifter = data_df.latitiude[data_df.WMO==2301619] # pink
# lon_drifter = data_df.longitude[data_df.WMO==2301619]
lat_drifter = data_df.latitiude[data_df.WMO==2301604] # green
lon_drifter = data_df.longitude[data_df.WMO==2301604]
# lat_drifter = data_df.latitiude[data_df.WMO==5301585] # orange
# lon_drifter = data_df.longitude[data_df.WMO==5301585]

# %%
# drifter data 
# create lists of drifter lat/lons to compare to particle positions
lon_drifter_daily = []
lat_drifter_daily = []

### CHANGE ###
# for ii in range(2,len(lon_drifter),4): #wk0
# for ii in range(30,len(lon_drifter),4): #wk1
# for ii in range(58,len(lon_drifter),4): #wk2
# for ii in range(86,len(lon_drifter),4): #wk3
# for ii in range(114,len(lon_drifter),4): #wk4
# for ii in range(142,len(lon_drifter),4): #wk5
# for ii in range(170,len(lon_drifter),4): #wk6
# for ii in range(198,len(lon_drifter),4): #wk7
# for ii in range(226,len(lon_drifter),4): #wk8
# for ii in range(254,len(lon_drifter),4): #wk9
# for ii in range(282,len(lon_drifter),4): #wk10
# for ii in range(310,len(lon_drifter),4): #wk11
# for ii in range(338,len(lon_drifter),4): #wk12
# for ii in range(366,len(lon_drifter),4): #wk13
# for ii in range(394,len(lon_drifter),4): #wk14
# for ii in range(422,len(lon_drifter),4): #wk15
# for ii in range(450,len(lon_drifter),4): #wk16
# for ii in range(478,len(lon_drifter),4): #wk17
# for ii in range(506,len(lon_drifter),4): #wk18
# for ii in range(534,len(lon_drifter),4): #wk19
# for ii in range(562,len(lon_drifter),4): #wk20
# for ii in range(590,len(lon_drifter),4): #wk21
# for ii in range(618,len(lon_drifter),4): #wk22
# for ii in range(646,len(lon_drifter),4): #wk23
# for ii in range(674,len(lon_drifter),4): #wk24
# for ii in range(702,len(lon_drifter),4): #wk25
# for ii in range(730,len(lon_drifter),4): #wk26
# for ii in range(758,len(lon_drifter),4): #wk27
# for ii in range(786,len(lon_drifter),4): #wk28
# for ii in range(814,len(lon_drifter),4): #wk29
# for ii in range(842,len(lon_drifter),4): #wk30
# for ii in range(870,len(lon_drifter),4): #wk31
# for ii in range(898,len(lon_drifter),4): #wk32
# for ii in range(926,len(lon_drifter),4): #wk33
# for ii in range(954,len(lon_drifter),4): #wk34
# for ii in range(982,len(lon_drifter),4): #wk35
# for ii in range(1010,len(lon_drifter),4): #wk36
# for ii in range(1038,len(lon_drifter),4): #wk37
# for ii in range(1066,len(lon_drifter),4): #wk38
# for ii in range(1094,len(lon_drifter),4): #wk39
# for ii in range(1122,len(lon_drifter),4): #wk40
# for ii in range(1150,len(lon_drifter),4): #wk41
# for ii in range(1178,len(lon_drifter),4): #wk42
for ii in range(1206,len(lon_drifter),4): #wk43
# for ii in range(1234,len(lon_drifter),4): #wk44
    lon_drifter_daily.append(lon_drifter.iloc[ii])
    lat_drifter_daily.append(lat_drifter.iloc[ii])
    
# print(np.shape(lat_drifter4))
# print(np.shape(lat_drifter4_daily))

# %%
# name of input/output files and location they are saved:

### CHANGE ###
# particle_input_file = '/gpfs/home/rpe16nbu/projects/ocpp_mo1/data/output/paper_data/validation/BoB_Cop_daily_validation_yellow.nc'
# particle_input_file = '/gpfs/home/rpe16nbu/projects/ocpp_mo1/data/output/paper_data/validation/BoB_Cop_daily_validation_red.nc'
# particle_input_file = '/gpfs/home/rpe16nbu/projects/ocpp_mo1/data/output/paper_data/validation/BoB_Cop_daily_validation_pink.nc'
# particle_input_file = '/gpfs/home/rpe16nbu/projects/ocpp_mo1/data/output/paper_data/validation/BoB_Cop_daily_validation_green.nc'
# particle_input_file = '/gpfs/home/rpe16nbu/projects/ocpp_mo1/data/output/paper_data/validation/BoB_Cop_daily_validation_orange.nc'
# particle_input_file = '/gpfs/home/rpe16nbu/projects/ocpp_mo1/data/output/paper_data/validation/BoB_ROMS_daily_validation_yellow.nc'
# particle_input_file = '/gpfs/home/rpe16nbu/projects/ocpp_mo1/data/output/paper_data/validation/BoB_ROMS_daily_validation_red.nc'
# particle_input_file = '/gpfs/home/rpe16nbu/projects/ocpp_mo1/data/output/paper_data/validation/BoB_ROMS_daily_validation_pink.nc'
particle_input_file = '/gpfs/home/rpe16nbu/projects/ocpp_mo1/data/output/paper_data/validation/BoB_ROMS_daily_validation_green.nc'
# particle_input_file = '/gpfs/home/rpe16nbu/projects/ocpp_mo1/data/output/paper_data/validation/BoB_ROMS_daily_validation_orange.nc'

# import particle data
openfile_p = Dataset(particle_input_file)
lon_p = openfile_p.variables['lon']
lat_p = openfile_p.variables['lat']
time_p = openfile_p.variables['time']

# %%
# how many starting positions are in each run (that have full weeks)
# yellow = 3
# red = 10
# pink = 8
# green = 45
# orange = 5

# %%
lon_wk = []
lat_wk = []

# %%
# particle data - yellow
# yellow/drifter4 finishes after wk3

### CHANGE ###
# for ii in range(0,lon_p.shape[0],4): # in steps of every 4th particle because there are 4 starting points in the yellow run
#     if 0 <= time_p[ii,0] < 604800: # wk0
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(1,lon_p.shape[0],4):
#     if 604800 <= time_p[ii,0] < 1209600: # wk1
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(2,lon_p.shape[0],4):
#     if 1209600 <= time_p[ii,0] < 1814400: # wk2
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# last starting point doesn't complete a week so can be ignored

# %%
# # particle data - red

# ### CHANGE ###
# for ii in range(0,lon_p.shape[0],11):
#     if 0 <= time_p[ii,0] < 604800:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(1,lon_p.shape[0],11):
#     if 604800 <= time_p[ii,0] < 1209600:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(2,lon_p.shape[0],11):
#     if 1209600 <= time_p[ii,0] < 1814400:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(3,lon_p.shape[0],11):
#     if 1814400 <= time_p[ii,0] < 2419200:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(4,lon_p.shape[0],11):
#     if 2419200 <= time_p[ii,0] < 3024000:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(5,lon_p.shape[0],11):
#     if 3024000 <= time_p[ii,0] < 3628800:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(6,lon_p.shape[0],11):
#     if 3628800 <= time_p[ii,0] < 4233600:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(7,lon_p.shape[0],11):
#     if 4233600 <= time_p[ii,0] < 4838400:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(8,lon_p.shape[0],11):
#     if 4838400 <= time_p[ii,0] < 5443200:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(9,lon_p.shape[0],11):
#     if 5443200 <= time_p[ii,0] < 6048000:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# # last starting point doesn't complete a week so can be ignored

# %%
# # particle data - pink

# ### CHANGE ###
# for ii in range(0,lon_p.shape[0],9): # in steps of every 9th particle because there are 9 starting points in the pink run
#     if 0 <= time_p[ii,0] < 604800: # wk0
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(1,lon_p.shape[0],9):
#     if 604800 <= time_p[ii,0] < 1209600: # wk1
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(2,lon_p.shape[0],9):
#     if 1209600 <= time_p[ii,0] < 1814400: # wk2
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(3,lon_p.shape[0],9):
#     if 1814400 <= time_p[ii,0] < 2419200: # wk3
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(4,lon_p.shape[0],9):
#     if 1814400 <= time_p[ii,0] < 2419200: # wk4
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(5,lon_p.shape[0],9):
#     if 2419200 <= time_p[ii,0] < 3024000: # wk5
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(6,lon_p.shape[0],9):
#     if 3024000 <= time_p[ii,0] < 3628800: # wk6
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(7,lon_p.shape[0],9):
#     if 3628800 <= time_p[ii,0] < 4233600: # wk7
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# # last starting point doesn't complete a week so can be ignored

# %%
# # particle data - green

# ### CHANGE ###
# for ii in range(0,lon_p.shape[0],46):
#     if 0 <= time_p[ii,0] < 604800:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(1,lon_p.shape[0],46):
#     if 604800 <= time_p[ii,0] < 1209600:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(2,lon_p.shape[0],46):
#     if 1209600 <= time_p[ii,0] < 1814400:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(3,lon_p.shape[0],46):
#     if 1814400 <= time_p[ii,0] < 2419200:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(4,lon_p.shape[0],46):
#     if 2419200 <= time_p[ii,0] < 3024000:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(5,lon_p.shape[0],46):
#     if 3024000 <= time_p[ii,0] < 3628800:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(6,lon_p.shape[0],46):
#     if 3628800 <= time_p[ii,0] < 4233600:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(7,lon_p.shape[0],46):
#     if 4233600 <= time_p[ii,0] < 4838400:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(8,lon_p.shape[0],46):
#     if 4838400 <= time_p[ii,0] < 5443200:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(9,lon_p.shape[0],46):
#     if 5443200 <= time_p[ii,0] < 6048000:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(10,lon_p.shape[0],46):
#     if 6048000 <= time_p[ii,0] < 6652800:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(11,lon_p.shape[0],46):
#     if 6652800 <= time_p[ii,0] < 7257600:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(12,lon_p.shape[0],46):
#     if 7257600 <= time_p[ii,0] < 7862400:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(13,lon_p.shape[0],46):
#     if 7862400 <= time_p[ii,0] < 8467200:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(14,lon_p.shape[0],46):
#     if 8467200 <= time_p[ii,0] < 9072000:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(15,lon_p.shape[0],46):
#     if 9072000 <= time_p[ii,0] < 9676800:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(16,lon_p.shape[0],46):
#     if 9676800 <= time_p[ii,0] < 10281600:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(17,lon_p.shape[0],46):
#     if 10281600 <= time_p[ii,0] < 10886400:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(18,lon_p.shape[0],46):
#     if 10886400 <= time_p[ii,0] < 11491200:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(19,lon_p.shape[0],46):
#     if 11491200 <= time_p[ii,0] < 12096000:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(20,lon_p.shape[0],46):
#     if 12096000 <= time_p[ii,0] < 12700800:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(21,lon_p.shape[0],46):
#     if 12700800 <= time_p[ii,0] < 13305600:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(22,lon_p.shape[0],46):
#     if 13305600 <= time_p[ii,0] < 13910400:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(23,lon_p.shape[0],46):
#     if 13910400 <= time_p[ii,0] < 14515200:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(24,lon_p.shape[0],46):
#     if 14515200 <= time_p[ii,0] < 15120000:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(25,lon_p.shape[0],46):
#     if 15120000 <= time_p[ii,0] < 15724800:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(26,lon_p.shape[0],46):
#     if 15724800 <= time_p[ii,0] < 16329600:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(27,lon_p.shape[0],46):
#     if 16329600 <= time_p[ii,0] < 16934400:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(28,lon_p.shape[0],46):
#     if 16934400 <= time_p[ii,0] < 17539200:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(29,lon_p.shape[0],46):
#     if 17539200 <= time_p[ii,0] < 18144000:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(30,lon_p.shape[0],46):
#     if 18144000 <= time_p[ii,0] < 18748800:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(31,lon_p.shape[0],46):
#     if 18748800 <= time_p[ii,0] < 19353600:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(32,lon_p.shape[0],46):
#     if 19353600 <= time_p[ii,0] < 19958400:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(33,lon_p.shape[0],46):
#     if 19958400 <= time_p[ii,0] < 20563200:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(34,lon_p.shape[0],46):
#     if 20563200 <= time_p[ii,0] < 21168000:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(35,lon_p.shape[0],46):
#     if 21168000 <= time_p[ii,0] < 21772800:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(36,lon_p.shape[0],46):
#     if 21772800 <= time_p[ii,0] < 22377600:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(37,lon_p.shape[0],46):
#     if 22377600 <= time_p[ii,0] < 22982400:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(38,lon_p.shape[0],46):
#     if 22982400 <= time_p[ii,0] < 23587200:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(39,lon_p.shape[0],46):
#     if 23587200 <= time_p[ii,0] < 24192000:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(40,lon_p.shape[0],46):
#     if 24192000 <= time_p[ii,0] < 24796800:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(41,lon_p.shape[0],46):
#     if 24796800 <= time_p[ii,0] < 25401600:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(42,lon_p.shape[0],46):
#     if 25401600 <= time_p[ii,0] < 26006400:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
for ii in range(43,lon_p.shape[0],46):
    if 26006400 <= time_p[ii,0] < 26611200:
        lon_wk.append(lon_p[ii,:8])
        lat_wk.append(lat_p[ii,:8])
# for ii in range(44,lon_p.shape[0],46):
#     if 26611200 <= time_p[ii,0] < 27216000:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# # last starting point doesn't complete a week so can be ignored

# %%
# # particle data - orange
# lon_wk = []
# lat_wk = []
# # yellow/drifter4 finishes after wk3

# ### CHANGE ###
# for ii in range(0,lon_p.shape[0],6):
#     if 0 <= time_p[ii,0] < 604800:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(1,lon_p.shape[0],6):
#     if 604800 <= time_p[ii,0] < 1209600:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(2,lon_p.shape[0],6):
#     if 1209600 <= time_p[ii,0] < 1814400:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(3,lon_p.shape[0],6):
#     if 1814400 <= time_p[ii,0] < 2419200:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# for ii in range(4,lon_p.shape[0],6):
#     if 2419200 <= time_p[ii,0] < 3024000:
#         lon_wk.append(lon_p[ii,:8])
#         lat_wk.append(lat_p[ii,:8])
# # last starting point doesn't complete a week so can be ignored

# %%
#separation distance
sep_dist_wk = np.zeros((100,8))
sep_dist_wk = sep_dist_wk*np.nan
for ii in range(np.size(sep_dist_wk,1)):
    for jj in range(np.size(sep_dist_wk,0)):
        if lon_wk[jj][ii]: # So it only uses non-beached particles in the calculation
#     print(f'lon_avg_wk = {lon_avg_wk[ii]}')
#     print(f'lon_drifter4 = {lon_drifter4_daily[ii]}')
#     print(f'lat_avg_wk = {lat_avg_wk[ii]}')
#     print(f'lat_drifter4 = {lat_drifter4_daily[ii]}')
            coords_drifter = (lat_drifter_daily[ii], lon_drifter_daily[ii])
            coords_particle = (lat_wk[jj][ii], lon_wk[jj][ii])
            sep_dist_wk[jj,ii] = geopy.distance.geodesic(coords_drifter, coords_particle).km

# %%
sep_dist_mean = np.nanmean(sep_dist_wk,0)
sep_dist_std = np.nanstd(sep_dist_wk,0)
print(sep_dist_mean)
print(sep_dist_std)
# Out:
# [1.85556441e-04 1.92657299e+01 2.23151052e+01 2.11808077e+01
#  1.61604390e+01 3.70999024e+01 6.13206976e+01 9.14926552e+01]
# [ 0.          4.30530019  7.62860025  8.7365123   8.8084312  14.00961253
#  17.41114554 20.46137987]

# %%
# mean cumulative separation distance - don't include inital value for each particle as that is the start position and is virtually unseparated from the drifter position.
sep_dist_wk_array = np.array(sep_dist_wk)
sep_dist_wk_without_pos1 = sep_dist_wk_array[:,1:]
cum_sep_dist_wk = np.nanmean(sep_dist_wk_without_pos1) # this is the total 
print(cum_sep_dist_wk)
# Out:
# 38.40504813337056

# %%
# write to file
with open(out_fname, 'w',newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=',')
    for ii in range(len(sep_dist_mean)):
        spamwriter.writerow(
            [sep_dist_mean[ii]]
        )
